# %%
# %load_ext sql

# %%
# %sql sqlite:///library2.db
# Out:
# Connecting to 'sqlite:///library2.db'

# %% [markdown]
# NOTE:
# The queries here are all for referencing the structure.
# All Table, entries listed below already exist.

# %% [markdown]
# # Add Table

# %% [markdown]
# Reminder: The table need to be created before adding entries.

# %% [markdown]
# ### Non-existing Table

# %%
# %%sql
#
# CREATE TABLE members (
#     memberID INT PRIMARY KEY,
#     memberName VARCHAR(50) NOT NULL,
#     balance DECIMAL(10,2) DEFAULT 0,
#     phone VARCHAR(15)
# );
#
# INSERT INTO members (memberID, memberName, balance, phone) VALUES
# (1, 'Ariel', 0, '000-000-0000'),
# (2, 'Aurora', 20, '111-111-1111'),
# (3, 'Belle', 0, '222-222-2222'),
# (4, 'Cinderalla', 0, '333-333-3333'),
# (5, 'Jasmine', 0, '444-444-4444'),
# (6, 'Merida', 0, '555-555-5555'),
# (7, 'Mulan', 0, '666-666-6666'),
# (8, 'Pocahontas', 0, '777-777-7777'),
# (9, 'Rapunzel', 45, '888-888-8888'),
# (10, 'Snow', 0, '999-999-9999');

# %% [markdown]
# ### Existing Table

# %%
# %%sql
# DROP TABLE IF EXISTS Staff;
#
# CREATE TABLE Staff (
#     staffID INTEGER PRIMARY KEY,
#     name TEXT NOT NULL,
#     phone TEXT,
#     mail TEXT,
#     role TEXT NOT NULL,
#     memberID INTEGER DEFAULT 0
# );
#
# INSERT INTO Staff (staffID, name, phone, mail, role, memberID) VALUES
# (1, 'Sponge', '012-345-6789', 'Sponge@mail.com', 'Administrator', 0),
# (2, 'Bob', '123-456-7890', 'Bob@mail.com', 'Administrator', 0),
# (3, 'Square', '234-567-8901', 'Square@mail.com', 'Administrator', 0),
# (4, 'Patrick', '345-678-9012', 'Patrick@mail.com', 'Librarian', 0),
# (5, 'Star', '456-789-0123', 'Star@mail.com', 'Librarian', 0),
# (6, 'Squid', '567-890-1234', 'Squid@mail.com', 'Librarian', 0),
# (7, 'Ward', '678-901-2345', 'Ward@mail.com', 'event_coordinator', 0),
# (8, 'Krabs', '789-012-3456', 'Krabs@mail.com', 'event_coordinator', 0),
# (9, 'Plankton', '890-123-4567', 'Plankton@mail.com', 'event_coordinator', 0),
# (10, 'Karen', '901-234-5678', 'Karen@mail.com', 'tech_staff', 0),
# (11, 'Sandy', '001-234-5678', 'Sandy@mail.com', 'tech_staff', 0),
# (12, 'Puff', '002-345-6789', 'Puff@mail.com', 'event_coordinator', 0),
# (13, 'Pearl', '003-456-7890', 'Pearl@mail.com', 'event_coordinator', 0),
# (14, 'Gary', '004-567-8901', 'Gary@mail.com', 'event_coordinator', 0),
# (15, 'Patchy', '005-678-9012', 'Patchy@mail.com', 'event_coordinator', 0);
# Out:
# Running query in 'sqlite:///library2.db'
# 15 rows affected.
# ++
# ||
# ++
# ++
